# %% [markdown]
# **Data Collection From YouTube**

# %%
# !pip install google-api-python-client pandas

# %%
import googleapiclient.discovery
from googleapiclient.discovery import build

# %%
import pandas as pd
api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyBMhriIZ1XBjhJxukaJVGiU5YggUNkN_g4"

# %% [markdown]
# **Extracting comments from videos on YouTube**

# %%
api_key = 'AIzaSyBMhriIZ1XBjhJxukaJVGiU5YggUNkN_g4'

# %%
youtube =  googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)

# %%
video_ids = [
    "giT0ytynSqg",
    "qYNweeDHiyU",
]
for vid in video_ids:
    print(f"extracting comments youtube videos: {vid}")
requestLine = youtube.commentThreads().list(
    part='snippet',
    videoId= vid, 
    maxResults=100,
)

responseLine = requestLine.execute()
for item in responseLine['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    print(comment)

print("\nCOMMENTS WITH KEYWORDS:")
keywords = ["AI", "Generative AI", "GenAI", "Artificial Intelligence"]
for item in responseLine['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    comment_lower = comment.lower()
    if any(keyword.lower() in comment_lower for keyword in keywords):
         print(comment)

# %% [markdown]
# **Collecting the data from Reddit dataset**

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re

# %%
df = pd.read_csv(r"C:\Users\Fateh\Documents\FYP_SENTIMENT_ANALYSIS\Data_Collection\Raw_Data\Reddit_raw.csv\comments.csv\comments.csv", low_memory=False)

# %% [markdown]
# **The dataset**

# %%
df.head()

# %% [markdown]
# **Data Collection from X dataset**

# %%
df_X = pd.read_csv(r"C:\Users\Fateh\Downloads\chatgpt.csv\chatgpt.csv")

# %%
df_X.head
